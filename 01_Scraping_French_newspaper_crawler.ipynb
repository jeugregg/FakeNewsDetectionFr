# %% [markdown]
# # Scraping french news with newspaper-crawler
#
# ## installation :
# pip install feedparser
#
# pip install scrapy
#
# pip install git+https://github.com/gbolmier/newspaper-crawler

# %% [markdown]
# ## Definitions

# %%
# your path folder to save results
PATH_FOLDER_SAVE = '../../data'

# %% [markdown]
# ## Helper functions

# %%
import shutil
# importing os module  
import os
# import datetime module
import datetime
    
def save_results_newpaper_crawler(your_source_folder, your_save_folder=None):
    '''
    Move results to "pressarticles_ #current date time#"
    '''
    PATH_SOURCE_ARTICLES =  "pressarticles"
    
    if your_source_folder is None:
        your_source_folder_articles = PATH_SOURCE_ARTICLES
    else:
        your_source_folder_articles = your_source_folder + \
            '/' + PATH_SOURCE_ARTICLES
    
    try:
        d = datetime.datetime.now()
        str_date = d.strftime("%Y%m%d_%H_%M_%S")
        # Directory 
        # saved files paths
        if your_save_folder is None:
            your_save_folder_articles =  your_source_folder_articles \
                + "_" + str_date
        # move directory
        shutil.move(your_source_folder_articles, your_save_folder_articles) 
        print("Directory '%s' created" %your_save_folder_articles)
    except:
        print('Folder {} does not exist!'.format(your_source_folder_articles))

# %% [markdown]
# ## Scraping

# %%
print("Stop process after around 5 min manually...")
# Out:
# Stop process after around 5 min manually...

# %%
import os
from newspaper_crawler import NewspaperCrawler

sources_to_crawl = [
    "futurasciences",
    "lefigaro",
    "lemonde",
    "liberation",
    "nouvelobs",
    "telerama",
]
# current folder
my_current_path = os.getcwd()
print("Current Folder: ", my_current_path)
# change to save folder
os.chdir(PATH_FOLDER_SAVE)
print("Scraping Results Folder: ", PATH_FOLDER_SAVE)
# scraping
crawler = NewspaperCrawler(sources_to_crawl, has_database=True)
crawler.start_crawling()
# Out:
# Current Folder:  /Users/gregory/Documents/CloudStationSinchon/Applications/python/OC_IML_projet_7/code/FakeNewsDetectionFr
# Scraping Results Folder:  ../../data
# 2019-12-26 07:43:02 [scrapy.crawler] INFO: Overridden settings: {'DOWNLOAD_DELAY': 2}
# 2019-12-26 07:43:02 [scrapy.extensions.telnet] INFO: Telnet Password: bb62c6007a7dcbff
# 2019-12-26 07:43:02 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2019-12-26 07:43:02 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-12-26 07:43:02 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-12-26 07:43:02 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-12-26 07:43:02 [scrapy.core.engine] INFO: Spider opened
# 2019-12-26 07:43:02 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-12-26 07:43:02 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2019-12-26 07:43:06 [scrapy.crawler] INFO: Overridden settings: {'DOWNLOAD_DELAY': 2}
# 2019-12-26 07:43:06 [scrapy.extensions.telnet] INFO: Telnet Password: 5eb4a9846368dc5f
# 2019-12-26 07:43:06 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2019-12-26 07:43:06 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-12-26 07:43:06 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-12-26 07:43:06 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-12-26 07:43:06 [scrapy.core.engine] INFO: Spider opened
# 2019-12-26 07:43:06 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-12-26 07:43:06 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6025
# 2019-12-26 07:43:09 [scrapy.crawler] INFO: Overridden settings: {'DOWNLOAD_DELAY': 2}
# 2019-12-26 07:43:09 [scrapy.extensions.telnet] INFO: Telnet Password: 6f106ef57e0567f2
# 2019-12-26 07:43:09 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 
57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.liberation.fr/direct/element/en-greve-lopera-de-paris-danse-contre-la-reforme-des-retraites_106954/?xtor=rss-450> (referer: None)
# 2019-12-26 07:43:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lefigaro.fr/actualite-france/fin-de-vie-la-caf-encourage-les-directives-anticipees-20191225> (referer: None)
# 2019-12-26 07:43:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://immobilier.lefigaro.fr/annonces/edito/acheter/j-emmenage/demenagement--4-conseils-pour-le-jour-j> (referer: None)
# 2019-12-26 07:43:58 [scrapy.core.scraper] ERROR: Spider error processing <GET https://immobilier.lefigaro.fr/annonces/edito/acheter/j-emmenage/demenagement--4-conseils-pour-le-jour-j> (referer: None)
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/scrapy/loader/processors.py", line 59, in __call__
#     value = func(value)
#   File "/anaconda3/lib/python3.7/site-packages/newspaper_crawler/loaders/lefigaro_loader.py", line 12, in clean_date
#     return re.search("[0-9]+/[0-9]+/[0-9]+", rawdata).group(0)
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/scrapy/loader/__init__.py", line 159, in _process_input_value
#     return proc(value)
#   File "/anaconda3/lib/python3.7/site-packages/scrapy/loader/processors.py", line 63, in __call__
#     (str(func), value, type(e).__name__, str(e)))
# ValueError: Error in Compose with <function LeFigaroLoader.clean_date at 0x1149fe048> value='Wednesday, December 25, 2019' error='AttributeError: 'NoneType' object has no attribute 'group''
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/anaconda3/lib/python3.7/site-packages/newspaper_crawler/spiders/lefigaro_spider.py", line 18, in parse
#     loader.add_xpath("date", "//time//text()")
#   File "/anaconda3/lib/python3.7/site-packages/scrapy/loader/__init__.py", line 181, in add_xpath
#     self.add_value(field_name, values, *processors, **kw)
#   File "/anaconda3/lib/python3.7/site-packages/scrapy/loader/__init__.py", line 78, in add_value
#     self._add_value(field_name, value)
#   File "/anaconda3/lib/python3.7/site-packages/scrapy/loader/__init__.py", line 92, in _add_value
#     processed_value = self._process_input_value(field_name, value)
#   File "/anaconda3/lib/python3.7/site-packages/scrapy/loader/__init__.py", line 164, in _process_input_value
#     value, type(e).__name__, str(e)))
# ValueError: Error with input processor Compose: field='date' value=['Wednesday, December 25, 2019'] error='ValueError: Error in Compose with <function LeFigaroLoader.clean_date at 0x1149fe048> value='Wednesday, December 25, 2019' error='AttributeError: 'NoneType' object has no attribute 'group'''
# 2019-12-26 07:43:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/idees/article/2019/12/26/nixon-clinton-trump-et-le-souffle-de-la-destitution_6024059_3232.html> (referer: None)
# 2019-12-26 07:44:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lefigaro.fr/societes/spacex-et-blue-origin-defient-les-europeens-dans-les-constellations-20191225> (referer: None)
# 2019-12-26 07:44:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://humeursnoires.blogs.liberation.fr/2019/12/25/anne-lafont-lart-et-la-race-lafricain-tout-contre-loeil-des-lumieres/> (referer: None)
# 2019-12-26 07:44:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https
07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/article/2019/12/25/carte-blanche-le-secret-evente-de-l-evaporation-des-gouttes-de-whisky_6024041_1650684.html> (referer: None)
# 2019-12-26 07:45:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/article/2019/12/25/infographie-la-realite-virtuelle-a-le-sens-du-toucher_6024039_1650684.html> (referer: None)
# 2019-12-26 07:45:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/article/2019/12/25/comment-les-idees-viennent-aux-scientifiques-a-l-age-de-8-ans-je-doutais-deja-de-mes-professeurs_6024040_1650684.html> (referer: None)
# 2019-12-26 07:45:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sport/article/2019/12/26/a-20-ans-fabio-quartararo-porte-les-espoirs-francais-en-moto_6024074_3242.html> (referer: None)
# 2019-12-26 07:45:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sport/article/2019/12/26/taylor-phinney-le-cyclisme-et-ses-99-d-emmerdes_6024070_3242.html> (referer: None)
# 2019-12-26 07:45:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/m-gastronomie/article/2019/12/25/le-champagne-veuve-clicquot-voit-plus-loin-que-les-cadeaux_6024029_4497540.html> (referer: None)
# 2019-12-26 07:45:17 [scrapy.core.engine] INFO: Closing spider (finished)
# 2019-12-26 07:45:17 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 19171,
#  'downloader/request_count': 52,
#  'downloader/request_method_count/GET': 52,
#  'downloader/response_bytes': 2060264,
#  'downloader/response_count': 52,
#  'downloader/response_status_count/200': 52,
#  'elapsed_time_seconds': 130.530927,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2019, 12, 26, 6, 45, 17, 446425),
#  'log_count/DEBUG': 135,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 53,
#  'memusage/max': 116670464,
#  'memusage/startup': 84959232,
#  'response_received_count': 52,
#  'scheduler/dequeued': 52,
#  'scheduler/dequeued/memory': 52,
#  'scheduler/enqueued': 52,
#  'scheduler/enqueued/memory': 52,
#  'start_time': datetime.datetime(2019, 12, 26, 6, 43, 6, 915498)}
# 2019-12-26 07:45:17 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
os.chdir(my_current_path)
print("Return Folder: ", os.getcwd())
# Out:
# Return Folder:  /Users/gregory/Documents/CloudStationSinchon/Applications/python/OC_IML_projet_7/code/FakeNewsDetectionFr

# %% [markdown]
# ## save json into data folder

# %%
PATH_FOLDER_SAVE
# Out:
# '../../data'

# %%
# move results to directory with date
save_results_newpaper_crawler(PATH_FOLDER_SAVE)
# Out:
# Directory '../../data/pressarticles_20191226_07_47_42' created

# %% [markdown]
# ## Read DataBase

# %%
# newspaper_db
import pandas as pd
import sqlite3

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect(PATH_FOLDER_SAVE + "/newspaper_db")
df = pd.read_sql_query("SELECT * from articles", con)

con.close()
# Out:
# 2019-12-26 07:49:19 [matplotlib] DEBUG: $HOME=/Users/gregory
# 2019-12-26 07:49:19 [matplotlib] DEBUG: CONFIGDIR=/Users/gregory/.matplotlib
# 2019-12-26 07:49:19 [matplotlib] DEBUG: matplotlib data path: /anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data
# 2019-12-26 07:49:19 [matplotlib] DEBUG: loaded rc file /anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc
# 2019-12-26 07:49:19 [matplotlib] DEBUG: matplotlib version 3.0.2
# 2019-12-26 07:49:19 [matplotlib] DEBUG: interactive is False
# 2019-12-26 07:49:19 [matplotlib] DEBUG: platform is darwin
# 2019-12-26 07:49:19 [matplotlib] DEBUG: loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'posix', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'site', 'os', 'stat', '_stat', 'posixpath', 'genericpath', 'os.path', '_collections_abc', '_sitebuiltins', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'functools', '_functools', 'mpl_toolkits', 'sphinxcontrib', 'zope', 'runpy', 'pkgutil', 'weakref', '_weakrefset', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'errno', '_posixsubprocess', 'select', 'selectors', 'collections.abc', 'math', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'logging', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'pwd', 'grp', 'traitlets', 'traitlets.traitlets', 'inspect', 'dis', 'opcode', '_opcode', 'six', 'struct', '_struct', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'locale', 'platform', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'decorator', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'gettext', 'ast', '_ast', 'ipython_genutils.path', 'random', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.text', 'textwrap', 'ipython_genutils.importstring', 'IPython.core.crashhandler', 'pprint', 'IPython.core.ultratb', 'pydoc', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'pygments.util', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_posix', 'pexpect', 'pexpect.exceptions', 'pexpect.utils', 'pexpect.expect', 'pexpect.pty_spawn', 'pty', 'tty', 'termios', 'ptyprocess', 'ptyprocess.ptyprocess', 'fcntl', 'resource', 'ptyprocess.util', 'pexpect.spawnbase', 'pexpect.run', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'ntpath', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'py ...

# %%
# Verify that result of SQL query is stored in the dataframe
df.tail()
# Out:
#      id_art                                                url      source  \
# 706     707  https://www.liberation.fr/france/2019/12/25/gr...  Liberation
# 707     708  https://www.liberation.fr/france/2019/12/25/in...  Liberation
# 708     709  https://www.liberation.fr/france/2019/12/25/te...  Liberation
# 709     710  https://www.liberation.fr/france/2019/12/25/19...  Liberation
# 710     711  https://www.liberation.fr/france/2019/12/25/le...  Liberation
#
#                                 author  \
# 706                     Franck Bouaziz
# 707  Sébastien Tronche, Sylvain Chazot
# 708                Bernadette Sauvaget
# 709                    Tonino Serafini
# 710                     Coralie Schaub
#
#                                                  title   theme  \
# 706  Grève à la SNCF et la RATP : les négociations ...  france
# 707  Interviews politiques : Violette Spillebout, G...  france
# 708  Tempêtes : chez Météo France, des leçons et de...  france
# 709      1999-2019: Les forêts reprennent leur souffle  france
# 710    «Le changement climatique fragilise les forêts»  france
#
#                                            description date_published  \
# 706  Dans les deux entreprises, dont les directions...     25/12/2019
# 707  Tous les vendredis, Chez Pol, la newsletter po...     25/12/2019
# 708  Les prévisionnistes ont adapté leur manière d’...     25/12/2019
# 709  Corse, Var, Aude… Cette année, de nombreux phé...     25/12/2019
# 710  Vingt ans après les tempêtes de 1999, et une l...     25/12/2019
#
#                                                   body
# 706  En cette trêve des confiseurs, c’est aussi la ...
# 707  «Oui, j’ai le seum, mais je vois aussi les tal...
# 708  Météo France avait vu venir Lothar. Dès le 23 ...
# 709  Inondations, toitures arrachées, arbres déraci...
# 710  En quoi les deux tempêtes de décembre 1999 ont...

# %%
df.shape
# Out:
# (711, 9)
